# %%
# %config IPCompleter.greedy=True

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Import the datetime module from the datetime library.
import time
from datetime import datetime

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=194d603a91da22fc5884faab74e0c1b2

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 604

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]
               
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | evensk
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | zeya
# Processing Record 4 of Set 1 | sitka
# Processing Record 5 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 6 of Set 1 | port alfred
# Processing Record 7 of Set 1 | tiksi
# Processing Record 8 of Set 1 | xiamen
# Processing Record 9 of Set 1 | bredasdorp
# Processing Record 10 of Set 1 | tuktoyaktuk
# Processing Record 11 of Set 1 | mataura
# Processing Record 12 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 13 of Set 1 | new norfolk
# Processing Record 14 of Set 1 | rio gallegos
# Processing Record 15 of Set 1 | busselton
# Processing Record 16 of Set 1 | borna
# Processing Record 17 of Set 1 | hobart
# Processing Record 18 of Set 1 | norman wells
# Processing Record 19 of Set 1 | cape town
# Processing Record 20 of Set 1 | motygino
# Processing Record 21 of Set 1 | yellowknife
# Processing Record 22 of Set 1 | banda aceh
# Processing Record 23 of Set 1 | kahului
# Processing Record 24 of Set 1 | albany
# Processing Record 25 of Set 1 | tecoanapa
# Processing Record 26 of Set 1 | namibe
# Processing Record 27 of Set 1 | vaini
# Processing Record 28 of Set 1 | havoysund
# Processing Record 29 of Set 1 | mpika
# Processing Record 30 of Set 1 | rikitea
# Processing Record 31 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 32 of Set 1 | tasiilaq
# Processing Record 33 of Set 1 | dikson
# Processing Record 34 of Set 1 | lerwick
# Processing Record 35 of Set 1 | willowmore
# Processing Record 36 of Set 1 | hofn
# Processing Record 37 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 38 of Set 1 | mahebourg
# Processing Record 39 of Set 1 | kapaa
# Processing Record 40 of Set 1 | tuatapere
# Processing Record 41 of Set 1 | kaitangata
# Processing Record 42 of Set 1 | belaya gora
# Processing Record 43 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 44 of Set 1 | hualmay
# Processing Record 45 of Set 1 | kijabe
# Processing Record 46 of Set 1 | pendleton
# Processing Record 47 of Set 1 | upernavik
# Processing Record 48 of Set 1 | reefton
# City not found. Skipping...
# Processing Record 49 of Set 1 | esperance
# Processing Record 50 of Set 1 | hilo
# Processing Record 1 of Set 2 | krasnovka
# Processing Record 2 of Set 2 | lagoa
# Processing Record 3 of Set 2 | kodiak
# Processing Record 4 of Set 2 | butaritari
# Processing Record 5 of Set 2 | ribeira grande
# Processing Record 6 of Set 2 | shasta lake
# Processing Record 7 of Set 2 | hermanus
# Processing Record 8 of Set 2 | tiarei
# Processing Record 9 of Set 2 | fallon
# Processing Record 10 of Set 2 | soyo
# Processing Record 11 of Set 2 | punta arenas
# Processing Record 12 of Set 2 | dalvik
# Processing Record 13 of Set 2 | astana
# Processing Record 14 of Set 2 | khorixas
# Processing Record 15 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 16 of Set 2 | carnarvon
# Processing Record 17 of Set 2 | qujing
# Processing Record 18 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 19 of Set 2 | mitsamiouli
# Processing Record 20 of Set 2 | atuona
# Processing Record 21 of Set 2 | mednogorsk
# Processing Record 22 of Set 2 | saint george
# Processing Record 23 of Set 2 | pangai
# Processing Record 24 of Set 2 | katsuura
# Processing Record 25 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 26 of Set 2 | adrar
# Processing Record 27 of Set 2 | bethel
# Processing Record 28 of Set 2 | thompson
# Processing Record 29 of Set 2 | ketchikan
# Processing Record 30 of Set 2 | baker city
# Processing Record 31 of Set 2 | constitucion
# Processing Record 32 of Set 2 | port keats
# Processing Record 33 of Set 2 | port elizabeth
# Processing Record 34 of Set 2 | jamestown
# Processing Record 35 of Set 2 | ixtapa
# Processing Record 36 of Set 2 | lasa
# Processing Record 37 of Set 2 | varhaug
# Processing Record 38 of Set 2 | mar del plata
# Processing Record 39 of Set 2 | castro
# Processing Record 40 of Set 2 | cidreira
# Processing Record 41 of Set 2 | san patricio
# Processing Record 42 of Set 2 | port lincoln
# Processing Record 43 of Set 2 | phan rang
# City not found. Skipping...
# Processing Record 44 of Set 2 | brownwood
# Processing Record 45 of Set 2 | ulladulla
# Processing Record 46 of Set 2 | weiden
# Processing Record 47 of Set 2 | karaton
# Processing Record 48 of Set 2 | kutum
# Processing Record 49 of Set 2 | saint-philippe
# Processing Record 50 of Set 2 | moose jaw
# Processing Record 1 of Set 3 | clyde river
# Processing Record 2 of Set 3 | cherskiy
# Processing Record 3 of Set 3 | bluff
# Processing Record 4 of Set 3 | lipari
# Processing Record 5 of Set 3 | nikolskoye
# Processing Record 6 of Set 3 | klaksvik
# Processing Record 7 of Set 3 | touros
# Processing Record 8 of Set 3 | oistins
# Processing Record 9 of Set 3 | mount gambier
# Processing Record 10 of Set 3 | mogadishu
# Processing Record 11 of Set 3 | mfou
# Processing Record 12 of Set 3 | baoqing
# Processing Record 13 of Set 3 | cabo san lucas
# Processing Record 14 of Set 3 | baghdad
# Processing Record 15 of Set 3 | richards bay
# Processing Record 16 of Set 3 | laguna
# Processing Record 17 of Set 3 | longyearbyen
# Processing Record 18 of Set 3 | acapulco
# Processing Record 19 of Set 3 | provideniya
# Processing Record 20 of Set 3 | kawana waters
# City not found. Skipping...
# Processing Record 21 of Set 3 | dicabisagan
# Processing Record 22 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 23 of Set 3 | jalu
# Processing Record 24 of Set 3 | sambava
# Processing Record 25 of Set 3 | kieta
# Processing Record 26 of Set 3 | nola
# Processing Record 27 of Set 3 | qaqortoq
# Processing Record 28 of Set 3 | ouadda
# Processing Record 29 of Set 3 | piran
# Processing Record 30 of Set 3 | nelson bay
# Processing Record 31 of Set 3 | mecca
# Processing Record 32 of Set 3 | chokurdakh
# Processing Record 33 of Set 3 | harper
# Processing Record 34 of Set 3 | rocha
# Processing Record 35 of Set 3 | arraial do cabo
# Processing Record 36 of Set 3 | capitao poco
# Processing Record 37 of Set 3 | lata
# Processing Record 38 of Set 3 | stepnoye
# Processing Record 39 of Set 3 | chuy
# Processing Record 40 of Set 3 | sirjan
# Processing Record 41 of Set 3 | kavieng
# Processing Record 42 of Set 3 | mao
# Processing Record 43 of Set 3 | husavik
# Processing Record 44 of Set 3 | nanortalik
# Processing Record 45 of Set 3 | semey
# Processing Record 46 of Set 3 | tacuarembo
# Processing Record 47 of Set 3 | novikovo
# Processing Record 48 of Set 3 | chichihualco
# Processing Record 49 of Set 3 | isangel
# Processing Record 50 of Set 3 | doha
# Processing Record 1 of Set 4 | khasan
# Processing Record 2 of Set 4 | camabatela
# Processing Record 3 of Set 4 | kuznechikha
# Processing Record 4 of Set 4 | maldonado
# Processing Record 5 of Set 4 | lorengau
# Processing Record 6 of Set 4 | faanui
# Processing Record 7 of Set 4 | padang
# Processing Record 8 of Set 4 | narsaq
# Processing Record 9 of Set 4 | puerto escondido
# Processing Record 10 of Set 4 | avarua
# Processing Record 11 of Set 4 | ilulissat
# Processing Record 12 of Set 4 | lakes entrance
# Processing Record 13 of Set 4 | porto novo
# Processing Record 14 of Set 4 | east london
# Processing Record 15 of Set 4 | westport
# Processing Record 16 of Set 4 | hovd
# Processing Record 17 of Set 4 | villeta
# Processing Record 18 of Set 4 | basavana bagevadi
# Processing Record 19 of Set 4 | alekseyevsk
# Processing Record 20 of Set 4 | bangui
# Processing Record 21 of Set 4 | karratha
# Processing Record 22 of Set 4 | luderitz
# Processing Record 23 of Set 4 | margate
# Processing Record 24 of Set 4 | vila velha
# Processing Record 25 of Set 4 | beaverlodge
# Processing Record 26 of Set 4 | bumiayu
# Processing Record 27 of Set 4 | lompoc
# Processing Record 28 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 29 of Set 4 | bereda
# Processing Record 30 of Set 4 | puerto ayora
# Processing Record 31 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 32 of Set 4 | at-bashi
# Processing Record 33 of Set 4 | sao filipe
# Processing Record 34 of Set 4 | lichinga
# Processing Record 35 of Set 4 | bealanana
# Processing Record 36 of Set 4 | basco
# Processing Record 37 of Set 4 | qaanaaq
# Processing Record 38 of Set 4 | muros
# Processing Record 39 of Set 4 | atbasar
# Processing Record 40 of Set 4 | iqaluit
# Processing Record 41 of Set 4 | merauke
# Processing Record 42 of Set 4 | barrow
# Processing Record 43 of Set 4 | komsomolskiy
# Processing Record 44 of Set 4 | stornoway
# Processing Record 45 of Set 4 | goderich
# Processing Record 46 of Set 4 | baruun-urt
# Processing Record 47 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 48 of Set 4 | kjollefjord
# Processing Record 49 of Set 4 | baboua
# City not found. Skipping...
# Processing Record 50 of Set 4 | umm lajj
# Processing Record 1 of Set 5 | maneadero
# Processing Record 2 of Set 5 | leh
# Processing Record 3 of Set 5 | martapura
# Processing Record 4 of Set 5 | lebu
# Processing Record 5 of Set 5 | kosovska mitrovica
# Processing Record 6 of Set 5 | georgetown
# Processing Record 7 of Set 5 | phonhong
# Processing Record 8 of Set 5 | aksu
# Processing Record 9 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 10 of Set 5 | dhidhdhoo
# Processing Record 11 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 12 of Set 5 | marsh harbour
# Processing Record 13 of Set 5 | bull savanna
# Processing Record 14 of Set 5 | kintinku
# Processing Record 15 of Set 5 | humaita
# Processing Record 16 of Set 5 | zaraza
# Processing Record 17 of Set 5 | pangnirtung
# Processing Record 18 of Set 5 | voh
# Processing Record 19 of Set 5 | berlevag
# Processing Record 20 of Set 5 | vardo
# Processing Record 21 of Set 5 | pombas
# Processing Record 22 of Set 5 | geraldton
# Processing Record 23 of Set 5 | prachuap khiri khan
# Processing Record 24 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 25 of Set 5 | morondava
# Processing Record 26 of Set 5 | grindavik
# Processing Record 27 of Set 5 | leningradskiy
# Processing Record 28 of Set 5 | ca mau
# Processing Record 29 of Set 5 | mantua
# Processing Record 30 of Set 5 | souillac
# Processing Record 31 of Set 5 | vieques
# Processing Record 32 of Set 5 | vila
# Processing Record 33 of Set 5 | dunayivtsi
# City not found. Skipping...
# Processing Record 34 of Set 5 | la ronge
# Processing Record 35 of Set 5 | saldanha
# Processing Record 36 of Set 5 | vanimo
# Processing Record 37 of Set 5 | talnakh
# Processing Record 38 of Set 5 | kpandu
# Processing Record 39 of Set 5 | guhagar
# Processing Record 40 of Set 5 | taoudenni
# Processing Record 41 of Set 5 | honolulu
# Processing Record 42 of Set 5 | guerrero negro
# Processing Record 43 of Set 5 | hithadhoo
# Processing Record 44 of Set 5 | atar
# Processing Record 45 of Set 5 | encruzilhada
# Processing Record 46 of Set 5 | pedraza
# Processing Record 47 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 48 of Set 5 | college
# Processing Record 49 of Set 5 | oppdal
# Processing Record 50 of Set 5 | longonjo
# Processing Record 1 of Set 6 | cairns
# Processing Record 2 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 3 of Set 6 | ahipara
# Processing Record 4 of Set 6 | sabla
# Processing Record 5 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 6 of Set 6 | borger
# Processing Record 7 of Set 6 | araouane
# Processing Record 8 of Set 6 | maumere
# Processing Record 9 of Set 6 | temaraia
# City not found. Skipping...
# Processing Record 10 of Set 6 | ternovka
# Processing Record 11 of Set 6 | adalaj
# Processing Record 12 of Set 6 | bengkulu
# Processing Record 13 of Set 6 | victor harbor
# Processing Record 14 of Set 6 | torbay
# Processing Record 15 of Set 6 | pangody
# Processing Record 16 of Set 6 | dianopolis
# City not found. Skipping...
# Processing Record 17 of Set 6 | solsvik
# City not found. Skipping...
# Processing Record 18 of Set 6 | hirara
# Processing Record 19 of Set 6 | tawkar
# City not found. Skipping...
# Processing Record 20 of Set 6 | lago da pedra
# Processing Record 21 of Set 6 | varaklani
# City not found. Skipping...
# Processing Record 22 of Set 6 | namie
# Processing Record 23 of Set 6 | dauphin
# Processing Record 24 of Set 6 | tromso
# Processing Record 25 of Set 6 | laiyang
# Processing Record 26 of Set 6 | wattegama
# Processing Record 27 of Set 6 | aksarka
# Processing Record 28 of Set 6 | chalchihuites
# Processing Record 29 of Set 6 | paucartambo
# City not found. Skipping...
# Processing Record 30 of Set 6 | tenenkou
# Processing Record 31 of Set 6 | prince rupert
# Processing Record 32 of Set 6 | abu zabad
# Processing Record 33 of Set 6 | monrovia
# Processing Record 34 of Set 6 | mujiayingzi
# Processing Record 35 of Set 6 | svetlogorsk
# Processing Record 36 of Set 6 | morant bay
# Processing Record 37 of Set 6 | buala
# Processing Record 38 of Set 6 | kisber
# Processing Record 39 of Set 6 | moindou
# Processing Record 40 of Set 6 | darlawn
# Processing Record 41 of Set 6 | shingu
# Processing Record 42 of Set 6 | sooke
# Processing Record 43 of Set 6 | hamilton
# Processing Record 44 of Set 6 | dingle
# Processing Record 45 of Set 6 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 46 of Set 6 | wonthaggi
# Processing Record 47 of Set 6 | hambantota
# Processing Record 48 of Set 6 | port augusta
# Processing Record 49 of Set 6 | pisco
# Processing Record 50 of Set 6 | russell
# Processing Record 1 of Set 7 | sao joao da barra
# Processing Record 2 of Set 7 | port hedland
# Processing Record 3 of Set 7 | haflong
# Processing Record 4 of Set 7 | airai
# Processing Record 5 of Set 7 | minab
# Processing Record 6 of Set 7 | mvuma
# Processing Record 7 of Set 7 | lufilufi
# Processing Record 8 of Set 7 | finote selam
# Processing Record 9 of Set 7 | tura
# Processing Record 10 of Set 7 | shimoda
# Processing Record 11 of Set 7 | kemin
# Processing Record 12 of Set 7 | yuzhnyy
# Processing Record 13 of Set 7 | garowe
# Processing Record 14 of Set 7 | caravelas
# Processing Record 15 of Set 7 | ancud
# Processing Record 16 of Set 7 | yanan
# City not found. Skipping...
# Processing Record 17 of Set 7 | kupang
# Processing Record 18 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 19 of Set 7 | pitimbu
# Processing Record 20 of Set 7 | thames
# Processing Record 21 of Set 7 | champerico
# Processing Record 22 of Set 7 | victoria
# Processing Record 23 of Set 7 | oromocto
# Processing Record 24 of Set 7 | staryy nadym
# Processing Record 25 of Set 7 | nguiu
# City not found. Skipping...
# Processing Record 26 of Set 7 | stokmarknes
# Processing Record 27 of Set 7 | vestmannaeyjar
# Processing Record 28 of Set 7 | worland
# Processing Record 29 of Set 7 | flin flon
# Processing Record 30 of Set 7 | pacifica
# Processing Record 31 of Set 7 | ambilobe
# Processing Record 32 of Set 7 | sorland
# Processing Record 33 of Set 7 | daxian
# City not found. Skipping...
# Processing Record 34 of Set 7 | tamiami
# Processing Record 35 of Set 7 | salalah
# Processing Record 36 of Set 7 | mae sai
# Processing Record 37 of Set 7 | brae
# Processing Record 38 of Set 7 | edea
# Processing Record 39 of Set 7 | haines junction
# Processing Record 40 of Set 7 | tchibanga
# Processing Record 41 of Set 7 | port blair
# Processing Record 42 of Set 7 | jatibarang
# Processing Record 43 of Set 7 | monterey
# Processing Record 44 of Set 7 | rudersdorf
# Processing Record 45 of Set 7 | rapina
# Processing Record 46 of Set 7 | aquiraz
# Processing Record 47 of Set 7 | bambanglipuro
# Processing Record 48 of Set 7 | pacific grove
# Processing Record 49 of Set 7 | teeli
# Processing Record 50 of Set 7 | de-kastri
# Processing Record 1 of Set 8 | ruatoria
# City not found. Skipping...
# Processing Record 2 of Set 8 | cam pha
# City not found. Skipping...
# Processing Record 3 of Set 8 | cheuskiny
# City not found. Skipping...
# Processing Record 4 of Set 8 | vallenar
# Processing Record 5 of Set 8 | camacha
# Processing Record 6 of Set 8 | khrebtovaya
# Processing Record 7 of Set 8 | saskylakh
# Processing Record 8 of Set 8 | knyaze-volkonskoye
# Processing Record 9 of Set 8 | fairbanks
# Processing Record 10 of Set 8 | vila do maio
# Processing Record 11 of Set 8 | hervey bay
# Processing Record 12 of Set 8 | savannah bight
# Processing Record 13 of Set 8 | bonthe
# Processing Record 14 of Set 8 | hami
# Processing Record 15 of Set 8 | trinidad
# Processing Record 16 of Set 8 | ikom
# Processing Record 17 of Set 8 | teknaf
# Processing Record 18 of Set 8 | nara
# Processing Record 19 of Set 8 | mayumba
# Processing Record 20 of Set 8 | nizwa
# Processing Record 21 of Set 8 | morehead
# Processing Record 22 of Set 8 | opuwo
# Processing Record 23 of Set 8 | clemson
# Processing Record 24 of Set 8 | play cu
# City not found. Skipping...
# Processing Record 25 of Set 8 | oranjemund
# Processing Record 26 of Set 8 | muli
# Processing Record 27 of Set 8 | narovchat
# Processing Record 28 of Set 8 | rio grande
# Processing Record 29 of Set 8 | yambio
# Processing Record 30 of Set 8 | safford
# Processing Record 31 of Set 8 | kirakira
# Processing Record 32 of Set 8 | jahangirabad
# Processing Record 33 of Set 8 | ponta do sol
# Processing Record 34 of Set 8 | nortelandia
# Processing Record 35 of Set 8 | bubaque
# Processing Record 36 of Set 8 | bayan
# Processing Record 37 of Set 8 | pevek
# Processing Record 38 of Set 8 | asfi
# Processing Record 39 of Set 8 | am timan
# Processing Record 40 of Set 8 | aklavik
# Processing Record 41 of Set 8 | yatou
# Processing Record 42 of Set 8 | mount isa
# Processing Record 43 of Set 8 | koshurnikovo
# Processing Record 44 of Set 8 | uravakonda
# Processing Record 45 of Set 8 | zachagansk
# City not found. Skipping...
# Processing Record 46 of Set 8 | lujiang
# Processing Record 47 of Set 8 | mandalgovi
# Processing Record 48 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 49 of Set 8 | alofi
# Processing Record 50 of Set 8 | runcu
# Processing Record 1 of Set 9 | tallahassee
# Processing Record 2 of Set 9 | bogale
# Processing Record 3 of Set 9 | vologda
# Processing Record 4 of Set 9 | hammerfest
# Processing Record 5 of Set 9 | kapoeta
# Processing Record 6 of Set 9 | bangkalan
# Processing Record 7 of Set 9 | sechura
# Processing Record 8 of Set 9 | severo-kurilsk
# Processing Record 9 of Set 9 | port-gentil
# Processing Record 10 of Set 9 | riyadh
# Processing Record 11 of Set 9 | la rioja
# Processing Record 12 of Set 9 | dongying
# Processing Record 13 of Set 9 | khatanga
# Processing Record 14 of Set 9 | sabzevar
# Processing Record 15 of Set 9 | dezhou
# Processing Record 16 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 17 of Set 9 | korbach
# Processing Record 18 of Set 9 | road town
# Processing Record 19 of Set 9 | socorro
# Processing Record 20 of Set 9 | camana
# Processing Record 21 of Set 9 | henties bay
# Processing Record 22 of Set 9 | yirol
# City not found. Skipping...
# Processing Record 23 of Set 9 | miles city
# Processing Record 24 of Set 9 | vysokogornyy
# Processing Record 25 of Set 9 | broome
# Processing Record 26 of Set 9 | steamboat springs
# Processing Record 27 of Set 9 | fukue
# Processing Record 28 of Set 9 | yulara
# Processing Record 29 of Set 9 | zhigansk
# Processing Record 30 of Set 9 | vigrestad
# Processing Record 31 of Set 9 | ojinaga
# Processing Record 32 of Set 9 | kavaratti
# Processing Record 33 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 34 of Set 9 | nome
# Processing Record 35 of Set 9 | saint anthony
# Processing Record 36 of Set 9 | grand gaube
# Processing Record 37 of Set 9 | stromness
# Processing Record 38 of Set 9 | lavrentiya
# Processing Record 39 of Set 9 | dubuque
# Processing Record 40 of Set 9 | ijaki
# City not found. Skipping...
# Processing Record 41 of Set 9 | huarmey
# Processing Record 42 of Set 9 | bumbuna
# Processing Record 43 of Set 9 | olden
# Processing Record 44 of Set 9 | medicine hat
# Processing Record 45 of Set 9 | flagstaff
# Processing Record 46 of Set 9 | manyana
# Processing Record 47 of Set 9 | hay river
# Processing Record 48 of Set 9 | glenwood springs
# Processing Record 49 of Set 9 | olafsvik
# Processing Record 50 of Set 9 | kailua
# Processing Record 1 of Set 10 | vao
# Processing Record 2 of Set 10 | shenkursk
# Processing Record 3 of Set 10 | torata
# Processing Record 4 of Set 10 | san quintin
# Processing Record 5 of Set 10 | alta floresta
# Processing Record 6 of Set 10 | balma
# Processing Record 7 of Set 10 | chastyye
# Processing Record 8 of Set 10 | gidam
# Processing Record 9 of Set 10 | marienburg
# Processing Record 10 of Set 10 | katobu
# Processing Record 11 of Set 10 | maridi
# Processing Record 12 of Set 10 | salta
# Processing Record 13 of Set 10 | batemans bay
# Processing Record 14 of Set 10 | baglung
# Processing Record 15 of Set 10 | mtwango
# Processing Record 16 of Set 10 | qasigiannguit
# Processing Record 17 of Set 10 | esso
# Processing Record 18 of Set 10 | artigas
# Processing Record 19 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 20 of Set 10 | coquimbo
# Processing Record 21 of Set 10 | dudinka
# Processing Record 22 of Set 10 | sola
# Processing Record 23 of Set 10 | dosso
# Processing Record 24 of Set 10 | san joaquin
# Processing Record 25 of Set 10 | wahiawa
# Processing Record 26 of Set 10 | tanout
# Processing Record 27 of Set 10 | tual
# Processing Record 28 of Set 10 | krasnoselkup
# Processing Record 29 of Set 10 | shiyan
# Processing Record 30 of Set 10 | kruisfontein
# Processing Record 31 of Set 10 | itoman
# Processing Record 32 of Set 10 | kovdor
# Processing Record 33 of Set 10 | opunake
# Processing Record 34 of Set 10 | iquique
# Processing Record 35 of Set 10 | teguise
# Processing Record 36 of Set 10 | el faiyum
# City not found. Skipping...
# Processing Record 37 of Set 10 | sao jose da coroa grande
# Processing Record 38 of Set 10 | bambous virieux
# Processing Record 39 of Set 10 | pemba
# Processing Record 40 of Set 10 | nanchang
# Processing Record 41 of Set 10 | fortuna
# Processing Record 42 of Set 10 | kalmunai
# Processing Record 43 of Set 10 | arrifes
# Processing Record 44 of Set 10 | pedernales
# Processing Record 45 of Set 10 | mondlo
# Processing Record 46 of Set 10 | kigonsera
# Processing Record 47 of Set 10 | avera
# Processing Record 48 of Set 10 | thinadhoo
# Processing Record 49 of Set 10 | ellensburg
# Processing Record 50 of Set 10 | vista hermosa
# Processing Record 1 of Set 11 | kununurra
# Processing Record 2 of Set 11 | teya
# Processing Record 3 of Set 11 | baghmara
# Processing Record 4 of Set 11 | chirkey
# Processing Record 5 of Set 11 | miramar
# Processing Record 6 of Set 11 | aulla
# Processing Record 7 of Set 11 | ingham
# Processing Record 8 of Set 11 | scarborough
# Processing Record 9 of Set 11 | rawson
# Processing Record 10 of Set 11 | horasan
# Processing Record 11 of Set 11 | quthing
# Processing Record 12 of Set 11 | chicama
# Processing Record 13 of Set 11 | jining
# Processing Record 14 of Set 11 | najran
# Processing Record 15 of Set 11 | los llanos de aridane
# Processing Record 16 of Set 11 | vila franca do campo
# Processing Record 17 of Set 11 | vargem alta
# Processing Record 18 of Set 11 | hobyo
# Processing Record 19 of Set 11 | alice springs
# Processing Record 20 of Set 11 | pompeia
# Processing Record 21 of Set 11 | atambua
# Processing Record 22 of Set 11 | tavda
# Processing Record 23 of Set 11 | aqtobe
# Processing Record 24 of Set 11 | la gaulette
# City not found. Skipping...
# Processing Record 25 of Set 11 | myitkyina
# Processing Record 26 of Set 11 | epinal
# Processing Record 27 of Set 11 | boa vista
# Processing Record 28 of Set 11 | port hardy
# Processing Record 29 of Set 11 | barawe
# City not found. Skipping...
# Processing Record 30 of Set 11 | novyy nekouz
# Processing Record 31 of Set 11 | kampene
# Processing Record 32 of Set 11 | biak
# Processing Record 33 of Set 11 | istanbul
# Processing Record 34 of Set 11 | puerto el triunfo
# Processing Record 35 of Set 11 | yate
# Processing Record 36 of Set 11 | shelburne
# Processing Record 37 of Set 11 | wamba
# Processing Record 38 of Set 11 | deputatskiy
# Processing Record 39 of Set 11 | camocim
# Processing Record 40 of Set 11 | jinhua
# Processing Record 41 of Set 11 | necochea
# Processing Record 42 of Set 11 | bucerias
# Processing Record 43 of Set 11 | ko samui
# Processing Record 44 of Set 11 | labuhan
# Processing Record 45 of Set 11 | birao
# Processing Record 46 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 47 of Set 11 | safranbolu
# Processing Record 48 of Set 11 | conde
# Processing Record 49 of Set 11 | asau
# Processing Record 50 of Set 11 | namatanai
# Processing Record 1 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 2 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 3 of Set 12 | emerald
# Processing Record 4 of Set 12 | lexington
# Processing Record 5 of Set 12 | vostok
# Processing Record 6 of Set 12 | ossora
# Processing Record 7 of Set 12 | ilheus
# Processing Record 8 of Set 12 | borovskoy
# Processing Record 9 of Set 12 | katsina
# Processing Record 10 of Set 12 | el balyana
# City not found. Skipping...
# Processing Record 11 of Set 12 | solovetskiy
# City not found. Skipping...
# Processing Record 12 of Set 12 | rampura
# Processing Record 13 of Set 12 | mehamn
# Processing Record 14 of Set 12 | lengshuijiang
# Processing Record 15 of Set 12 | shelton
# Processing Record 16 of Set 12 | bushehr
# Processing Record 17 of Set 12 | abha
# Processing Record 18 of Set 12 | madimba
# Processing Record 19 of Set 12 | zelenoborskiy
# Processing Record 20 of Set 12 | urumqi
# Processing Record 21 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 22 of Set 12 | puerto ayacucho
# Processing Record 23 of Set 12 | seydisehir
# Processing Record 24 of Set 12 | walvis bay
# Processing Record 25 of Set 12 | onega
# Processing Record 26 of Set 12 | tanete
# Processing Record 27 of Set 12 | portland
# Processing Record 28 of Set 12 | havre-saint-pierre
# Processing Record 29 of Set 12 | jinji
# Processing Record 30 of Set 12 | saint-augustin
# Processing Record 31 of Set 12 | kalabo
# Processing Record 32 of Set 12 | marmande
# Processing Record 33 of Set 12 | ponta delgada
# Processing Record 34 of Set 12 | llanes
# Processing Record 35 of Set 12 | puerto del rosario
# Processing Record 36 of Set 12 | vestmanna
# Processing Record 37 of Set 12 | boralday
# Processing Record 38 of Set 12 | burns lake
# Processing Record 39 of Set 12 | yushu
# Processing Record 40 of Set 12 | biu
# Processing Record 41 of Set 12 | salinopolis
# Processing Record 42 of Set 12 | kisangani
# Processing Record 43 of Set 12 | turukhansk
# Processing Record 44 of Set 12 | havelock
# Processing Record 45 of Set 12 | arlit
# Processing Record 46 of Set 12 | diffa
# Processing Record 47 of Set 12 | yeletskiy
# City not found. Skipping...
# Processing Record 48 of Set 12 | stephenville
# Processing Record 49 of Set 12 | fort wayne
# Processing Record 50 of Set 12 | oshkosh
# Processing Record 1 of Set 13 | ostrovnoy
# Processing Record 2 of Set 13 | casino
# Processing Record 3 of Set 13 | along
# Processing Record 4 of Set 13 | arkhangelos
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Evensk      RU  61.9500  159.2333     28.62        78         100
# 1      Ushuaia      AR -54.8000  -68.3000     40.66        81         100
# 2         Zeya      RU  53.7500  127.2667     32.14        44          97
# 3        Sitka      US  57.0531 -135.3300     42.84        89          90
# 4  Port Alfred      ZA -33.5906   26.8910     64.18        72          52
# 5        Tiksi      RU  71.6872  128.8694     -4.58       100          97
# 6       Xiamen      CN  24.4798  118.0819     78.85        83           0
# 7   Bredasdorp      ZA -34.5322   20.0403     63.70        50          20
# 8  Tuktoyaktuk      CA  69.4541 -133.0374     30.85        91         100
# 9      Mataura      NZ -46.1927  168.8643     50.49        92           9
#
#    Wind Speed Current Description
# 0       16.71     overcast clouds
# 1       13.80          light rain
# 2        4.74     overcast clouds
# 3        3.58     overcast clouds
# 4        5.01       broken clouds
# 5        3.11     overcast clouds
# 6        8.95           clear sky
# 7       10.38          few clouds
# 8        4.18     overcast clouds
# 9        4.79           clear sky

# %%
# Create the output file (CSV).
output_data_file = "../Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
